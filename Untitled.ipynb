# %%
#kütüphanelerin deklerasyonu
import pandas as pd

# %%
import matplotlib.pyplot as plt

import seaborn as sns
sns.set_style('darkgrid')
sns.set(font_scale=1.5)

# %%
# veri setinin GitHub’tan alınması
df =pd.read_csv('https://raw.githubusercontent.com/LearnDataSci/article-resources/master/Essential%20Statistics/middle_tn_schools.csv')

# %%
df.sample(5)
# Out:
#                             name  school_rating    size  reduced_lunch  \
# 112     Highland Park Elementary            2.0   348.0           88.0
# 56              Discovery School            5.0   411.0            8.0
# 109                  Head Middle            4.0   587.0           48.0
# 330    West Wilson Middle School            4.0  1153.0           30.0
# 120  Homer Pittard Campus School            4.0   248.0           12.0
#
#      state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# 112                 34.6                 25.6             11.6         Public
# 56                  99.6                 99.8             15.2  Public Magnet
# 109                 83.4                 86.5             17.7  Public Magnet
# 330                 80.2                 78.9             19.8         Public
# 120                 83.6                 95.1             16.5         Public
#
#      avg_score_15  avg_score_16  full_time_teachers  percent_black  \
# ...

# %%
dict = {'Öğrenci_01':[69,75,100], 'Öğrenci_02':[80,90,100], 'Öğrenci_03': [80, 85, 95]}

# %%
import pandas as pd
dm.dataframe(dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-9ff1d246aafc> in <module>
#       1 import pandas as pd
# ----> 2 dm.dataframe(dict)
#
# NameError: name 'dm' is not defined

# %%
df.head()
# Out:
#                           name  school_rating   size  reduced_lunch  \
# 0  Allendale Elementary School            5.0  851.0           10.0
# 1          Anderson Elementary            2.0  412.0           71.0
# 2             Avoca Elementary            4.0  482.0           43.0
# 3                Bailey Middle            0.0  394.0           91.0
# 4          Barfield Elementary            4.0  948.0           26.0
#
#    state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# 0                 90.2                 95.8             15.7         Public
# 1                 32.8                 37.3             12.8         Public
# 2                 78.4                 83.6             16.6         Public
# 3                  1.6                  1.0             13.1  Public Magnet
# 4                 85.3                 89.2             14.8         Public
#
#    avg_score_15  avg_score_16  full_time_teachers  percent_black  \
# ...

# %%
import sys
sys.version
# Out:
# '3.6.6 |Anaconda, Inc.| (default, Jun 28 2018, 17:14:51) \n[GCC 7.2.0]'

# %%
sicakdeg=[19,10,13,12,11,9,8]

# %%
print(sicakdeg[-5:-2])
# Out:
# [13, 12, 11]

# %%
format(sys.version)
# Out:
# '3.6.6 |Anaconda, Inc.| (default, Jun 28 2018, 17:14:51) \n[GCC 7.2.0]'

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.0.0'

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=347, step=1),
#  Index(['name', 'school_rating', 'size', 'reduced_lunch', 'state_percentile_16',
#         'state_percentile_15', 'stu_teach_ratio', 'school_type', 'avg_score_15',
#         'avg_score_16', 'full_time_teachers', 'percent_black', 'percent_white',
#         'percent_asian', 'percent_hispanic'],
#        dtype='object')]

# %%
df.max()
# Out:
# name                    Wright Middle
# school_rating                       5
# size                             2314
# reduced_lunch                      98
# state_percentile_16              99.8
# state_percentile_15              99.8
# stu_teach_ratio                   111
# school_type            Public Virtual
# avg_score_15                       99
# avg_score_16                     98.9
# full_time_teachers                140
# percent_black                    97.4
# percent_white                    99.7
# percent_asian                    21.1
# percent_hispanic                 65.2
# dtype: object

# %%
df.min()
# Out:
# name                   Allendale Elementary School
# school_rating                                    0
# size                                            53
# reduced_lunch                                    2
# state_percentile_16                            0.2
# state_percentile_15                            0.6
# stu_teach_ratio                                4.7
# school_type                                 Public
# avg_score_15                                   1.5
# avg_score_16                                   0.1
# full_time_teachers                               2
# percent_black                                    0
# percent_white                                  1.1
# percent_asian                                    0
# percent_hispanic                                 0
# dtype: object

# %%
df.dtypes
# Out:
# name                    object
# school_rating          float64
# size                   float64
# reduced_lunch          float64
# state_percentile_16    float64
# state_percentile_15    float64
# stu_teach_ratio        float64
# school_type             object
# avg_score_15           float64
# avg_score_16           float64
# full_time_teachers     float64
# percent_black          float64
# percent_white          float64
# percent_asian          float64
# percent_hispanic       float64
# dtype: object

# %%
df.count()
# Out:
# name                   347
# school_rating          347
# size                   347
# reduced_lunch          347
# state_percentile_16    347
# state_percentile_15    341
# stu_teach_ratio        347
# school_type            347
# avg_score_15           341
# avg_score_16           347
# full_time_teachers     347
# percent_black          347
# percent_white          347
# percent_asian          347
# percent_hispanic       347
# dtype: int64

# %%
df.shape
# Out:
# (347, 15)

# %%
import keras
keras.__version__
# Out:
# '2.3.1'

# %%
print(df)
# Out:
#                                             name  school_rating    size  \
# 0                    Allendale Elementary School            5.0   851.0
# 1                            Anderson Elementary            2.0   412.0
# 2                               Avoca Elementary            4.0   482.0
# 3                                  Bailey Middle            0.0   394.0
# 4                            Barfield Elementary            4.0   948.0
# 5                 Barkers Mill Elementary School            4.0   893.0
# 6                           Barksdale Elementary            4.0   580.0
# 7                               Beech Elementary            5.0   612.0
# 8                       Beech Senior High School            4.0  1274.0
# 9                                Bellevue Middle            3.0   680.0
# 10                          Bellshire Elementary            0.0   539.0
# 11              Benny C. Bills Elementary School            3.0   705.0
# ...

# %%
df[df['school_rating']==4].head()
# Out:
#                              name  school_rating    size  reduced_lunch  \
# 2                Avoca Elementary            4.0   482.0           43.0
# 4             Barfield Elementary            4.0   948.0           26.0
# 5  Barkers Mill Elementary School            4.0   893.0           48.0
# 6            Barksdale Elementary            4.0   580.0           58.0
# 8        Beech Senior High School            4.0  1274.0           21.0
#
#    state_percentile_16  state_percentile_15  stu_teach_ratio school_type  \
# 2                 78.4                 83.6             16.6      Public
# 4                 85.3                 89.2             14.8      Public
# 5                 78.1                 76.4             13.9      Public
# 6                 83.2                 74.6             13.8      Public
# 8                 82.5                 77.9             14.9      Public
#
#    avg_score_15  avg_score_16  full_time_teachers  percent_black  \
# ...

# %%
df['school_rating']
# Out:
# 0      5.0
# 1      2.0
# 2      4.0
# 3      0.0
# 4      4.0
# 5      4.0
# 6      4.0
# 7      5.0
# 8      4.0
# 9      3.0
# 10     0.0
# 11     3.0
# 12     3.0
# 13     5.0
# 14     4.0
# 15     4.0
# 16     2.0
# 17     3.0
# 18     4.0
# 19     1.0
# 20     5.0
# 21     5.0
# 22     4.0
# 23     4.0
# 24     0.0
# 25     3.0
# 26     2.0
# 27     0.0
# 28     0.0
# 29     5.0
#       ...
# 317    4.0
# 318    0.0
# 319    4.0
# 320    4.0
# 321    2.0
# 322    3.0
# 323    2.0
# 324    2.0
# 325    4.0
# 326    3.0
# 327    4.0
# 328    4.0
# 329    3.0
# 330    4.0
# 331    2.0
# 332    4.0
# 333    4.0
# 334    3.0
# 335    3.0
# 336    4.0
# 337    1.0
# 338    3.0
# 339    2.0
# 340    3.0
# 341    4.0
# 342    3.0
# 343    5.0
# 344    4.0
# 345    5.0
# 346    0.0
# Name: school_rating, Length: 347, dtype: float64

# %%
df.loc[:,'school_rating']
# Out:
# 0      5.0
# 1      2.0
# 2      4.0
# 3      0.0
# 4      4.0
# 5      4.0
# 6      4.0
# 7      5.0
# 8      4.0
# 9      3.0
# 10     0.0
# 11     3.0
# 12     3.0
# 13     5.0
# 14     4.0
# 15     4.0
# 16     2.0
# 17     3.0
# 18     4.0
# 19     1.0
# 20     5.0
# 21     5.0
# 22     4.0
# 23     4.0
# 24     0.0
# 25     3.0
# 26     2.0
# 27     0.0
# 28     0.0
# 29     5.0
#       ...
# 317    4.0
# 318    0.0
# 319    4.0
# 320    4.0
# 321    2.0
# 322    3.0
# 323    2.0
# 324    2.0
# 325    4.0
# 326    3.0
# 327    4.0
# 328    4.0
# 329    3.0
# 330    4.0
# 331    2.0
# 332    4.0
# 333    4.0
# 334    3.0
# 335    3.0
# 336    4.0
# 337    1.0
# 338    3.0
# 339    2.0
# 340    3.0
# 341    4.0
# 342    3.0
# 343    5.0
# 344    4.0
# 345    5.0
# 346    0.0
# Name: school_rating, Length: 347, dtype: float64

# %%
df.loc[:,['school_rating','size']]
# Out:
#      school_rating    size
# 0              5.0   851.0
# 1              2.0   412.0
# 2              4.0   482.0
# 3              0.0   394.0
# 4              4.0   948.0
# 5              4.0   893.0
# 6              4.0   580.0
# 7              5.0   612.0
# 8              4.0  1274.0
# 9              3.0   680.0
# 10             0.0   539.0
# 11             3.0   705.0
# 12             3.0   830.0
# 13             5.0   880.0
# 14             4.0  2021.0
# 15             4.0  1212.0
# 16             2.0   489.0
# 17             3.0   361.0
# 18             4.0   310.0
# 19             1.0   453.0
# 20             5.0  1689.0
# 21             5.0  1261.0
# 22             4.0   694.0
# 23             4.0   460.0
# 24             0.0   365.0
# 25             3.0   616.0
# 26             2.0   631.0
# 27             0.0   279.0
# 28             0.0   587.0
# 29             5.0   583.0
# ..             ...     ...
# 317            4.0   461.0
# 318            0.0   351.0
# ...

# %%
df.loc[12,['school_rating','name']]
# Out:
# school_rating                       3
# name             Black Fox Elementary
# Name: 12, dtype: object

# %%
df.loc[5,['name']]
# Out:
# name    Barkers Mill Elementary School
# Name: 5, dtype: object

# %%
df.loc[:]
# Out:
#                                             name  school_rating    size  \
# 0                    Allendale Elementary School            5.0   851.0
# 1                            Anderson Elementary            2.0   412.0
# 2                               Avoca Elementary            4.0   482.0
# 3                                  Bailey Middle            0.0   394.0
# 4                            Barfield Elementary            4.0   948.0
# 5                 Barkers Mill Elementary School            4.0   893.0
# 6                           Barksdale Elementary            4.0   580.0
# 7                               Beech Elementary            5.0   612.0
# 8                       Beech Senior High School            4.0  1274.0
# 9                                Bellevue Middle            3.0   680.0
# 10                          Bellshire Elementary            0.0   539.0
# 11              Benny C. Bills Elementary School            3.0   705.0
# ...

# %%
df.iloc[:]
# Out:
#                                             name  school_rating    size  \
# 0                    Allendale Elementary School            5.0   851.0
# 1                            Anderson Elementary            2.0   412.0
# 2                               Avoca Elementary            4.0   482.0
# 3                                  Bailey Middle            0.0   394.0
# 4                            Barfield Elementary            4.0   948.0
# 5                 Barkers Mill Elementary School            4.0   893.0
# 6                           Barksdale Elementary            4.0   580.0
# 7                               Beech Elementary            5.0   612.0
# 8                       Beech Senior High School            4.0  1274.0
# 9                                Bellevue Middle            3.0   680.0
# 10                          Bellshire Elementary            0.0   539.0
# 11              Benny C. Bills Elementary School            3.0   705.0
# ...

# %%
print(df)
# Out:
#                                             name  school_rating    size  \
# 0                    Allendale Elementary School            5.0   851.0
# 1                            Anderson Elementary            2.0   412.0
# 2                               Avoca Elementary            4.0   482.0
# 3                                  Bailey Middle            0.0   394.0
# 4                            Barfield Elementary            4.0   948.0
# 5                 Barkers Mill Elementary School            4.0   893.0
# 6                           Barksdale Elementary            4.0   580.0
# 7                               Beech Elementary            5.0   612.0
# 8                       Beech Senior High School            4.0  1274.0
# 9                                Bellevue Middle            3.0   680.0
# 10                          Bellshire Elementary            0.0   539.0
# 11              Benny C. Bills Elementary School            3.0   705.0
# ...

# %%
df.tail(-1)
# Out:
#                                             name  school_rating    size  \
# 1                            Anderson Elementary            2.0   412.0
# 2                               Avoca Elementary            4.0   482.0
# 3                                  Bailey Middle            0.0   394.0
# 4                            Barfield Elementary            4.0   948.0
# 5                 Barkers Mill Elementary School            4.0   893.0
# 6                           Barksdale Elementary            4.0   580.0
# 7                               Beech Elementary            5.0   612.0
# 8                       Beech Senior High School            4.0  1274.0
# 9                                Bellevue Middle            3.0   680.0
# 10                          Bellshire Elementary            0.0   539.0
# 11              Benny C. Bills Elementary School            3.0   705.0
# 12                          Black Fox Elementary            3.0   830.0
# ...

# %%
df.loc[0:5]
# Out:
#                              name  school_rating   size  reduced_lunch  \
# 0     Allendale Elementary School            5.0  851.0           10.0
# 1             Anderson Elementary            2.0  412.0           71.0
# 2                Avoca Elementary            4.0  482.0           43.0
# 3                   Bailey Middle            0.0  394.0           91.0
# 4             Barfield Elementary            4.0  948.0           26.0
# 5  Barkers Mill Elementary School            4.0  893.0           48.0
#
#    state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# 0                 90.2                 95.8             15.7         Public
# 1                 32.8                 37.3             12.8         Public
# 2                 78.4                 83.6             16.6         Public
# 3                  1.6                  1.0             13.1  Public Magnet
# 4                 85.3                 89.2             14.8         Public
# ...

# %%
df.iloc[0:5]
# Out:
#                           name  school_rating   size  reduced_lunch  \
# 0  Allendale Elementary School            5.0  851.0           10.0
# 1          Anderson Elementary            2.0  412.0           71.0
# 2             Avoca Elementary            4.0  482.0           43.0
# 3                Bailey Middle            0.0  394.0           91.0
# 4          Barfield Elementary            4.0  948.0           26.0
#
#    state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# 0                 90.2                 95.8             15.7         Public
# 1                 32.8                 37.3             12.8         Public
# 2                 78.4                 83.6             16.6         Public
# 3                  1.6                  1.0             13.1  Public Magnet
# 4                 85.3                 89.2             14.8         Public
#
#    avg_score_15  avg_score_16  full_time_teachers  percent_black  \
# ...

# %%
df.iloc[[2,3,5]]
# Out:
#                              name  school_rating   size  reduced_lunch  \
# 2                Avoca Elementary            4.0  482.0           43.0
# 3                   Bailey Middle            0.0  394.0           91.0
# 5  Barkers Mill Elementary School            4.0  893.0           48.0
#
#    state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# 2                 78.4                 83.6             16.6         Public
# 3                  1.6                  1.0             13.1  Public Magnet
# 5                 78.1                 76.4             13.9         Public
#
#    avg_score_15  avg_score_16  full_time_teachers  percent_black  \
# 2          75.7          73.0                29.0            1.0
# 3           2.1           4.4                30.0           80.7
# 5          69.4          72.3                64.0           28.6
#
#    percent_white  percent_asian  percent_hispanic
# 2           91.5            1.2               4.4
# ...

# %%
df.loc[[2,3,5]]
# Out:
#                              name  school_rating   size  reduced_lunch  \
# 2                Avoca Elementary            4.0  482.0           43.0
# 3                   Bailey Middle            0.0  394.0           91.0
# 5  Barkers Mill Elementary School            4.0  893.0           48.0
#
#    state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# 2                 78.4                 83.6             16.6         Public
# 3                  1.6                  1.0             13.1  Public Magnet
# 5                 78.1                 76.4             13.9         Public
#
#    avg_score_15  avg_score_16  full_time_teachers  percent_black  \
# 2          75.7          73.0                29.0            1.0
# 3           2.1           4.4                30.0           80.7
# 5          69.4          72.3                64.0           28.6
#
#    percent_white  percent_asian  percent_hispanic
# 2           91.5            1.2               4.4
# ...

# %%
df.at[3,'name']
# Out:
# 'Bailey Middle'

# %%
df.iat[14,7]
# Out:
# 'Public'

# %%
df['name']
# Out:
# 0                      Allendale Elementary School
# 1                              Anderson Elementary
# 2                                 Avoca Elementary
# 3                                    Bailey Middle
# 4                              Barfield Elementary
# 5                   Barkers Mill Elementary School
# 6                             Barksdale Elementary
# 7                                 Beech Elementary
# 8                         Beech Senior High School
# 9                                  Bellevue Middle
# 10                            Bellshire Elementary
# 11                Benny C. Bills Elementary School
# 12                            Black Fox Elementary
# 13                      Blackman Elementary School
# 14                            Blackman High School
# 15                          Blackman Middle School
# 16                           Bluff City Elementary
# 17                        Bluff City Middle School
# ...

# %%
df.name.head()
# Out:
# 0    Allendale Elementary School
# 1            Anderson Elementary
# 2               Avoca Elementary
# 3                  Bailey Middle
# 4            Barfield Elementary
# Name: name, dtype: object

# %%
print(df.columns)
# Out:
# Index(['name', 'school_rating', 'size', 'reduced_lunch', 'state_percentile_16',
#        'state_percentile_15', 'stu_teach_ratio', 'school_type', 'avg_score_15',
#        'avg_score_16', 'full_time_teachers', 'percent_black', 'percent_white',
#        'percent_asian', 'percent_hispanic'],
#       dtype='object')

# %%
import numpy as np
pd.pivot_table(df,index=['name','school_rating'], values=['size'], aggfunc=[np.mean,np.sum])
# Out:
#                                                              mean     sum
#                                                              size    size
# name                                        school_rating
# Allendale Elementary School                 5.0             851.0   851.0
# Anderson Elementary                         2.0             412.0   412.0
# Avoca Elementary                            4.0             482.0   482.0
# Bailey Middle                               0.0             394.0   394.0
# Barfield Elementary                         4.0             948.0   948.0
# Barkers Mill Elementary School              4.0             893.0   893.0
# Barksdale Elementary                        4.0             580.0   580.0
# Beech Elementary                            5.0             612.0   612.0
# Beech Senior High School                    4.0            1274.0  1274.0
# Bellevue Middle                             3.0             680.0   680.0
# ...

# %%
print(df.iloc[5])
# Out:
# name                   Barkers Mill Elementary School
# school_rating                                       4
# size                                              893
# reduced_lunch                                      48
# state_percentile_16                              78.1
# state_percentile_15                              76.4
# stu_teach_ratio                                  13.9
# school_type                                    Public
# avg_score_15                                     69.4
# avg_score_16                                     72.3
# full_time_teachers                                 64
# percent_black                                    28.6
# percent_white                                    39.9
# percent_asian                                     2.2
# percent_hispanic                                 17.8
# Name: 5, dtype: object

# %%
print(df.iloc[0])
# Out:
# name                   Allendale Elementary School
# school_rating                                    5
# size                                           851
# reduced_lunch                                   10
# state_percentile_16                           90.2
# state_percentile_15                           95.8
# stu_teach_ratio                               15.7
# school_type                                 Public
# avg_score_15                                  89.4
# avg_score_16                                  85.2
# full_time_teachers                              54
# percent_black                                  2.9
# percent_white                                 85.5
# percent_asian                                  1.6
# percent_hispanic                               5.6
# Name: 0, dtype: object

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=347, step=1)

# %%
df[['reduced_lunch','school_rating']].groupby(['school_rating'])

# %%
df[['reduced_lunch','school_rating']].corr()
# Out:
#                reduced_lunch  school_rating
# reduced_lunch       1.000000      -0.815757
# school_rating      -0.815757       1.000000

# %%
print(df['percent_black'])
# Out:
# 0       2.9
# 1       3.9
# 2       1.0
# 3      80.7
# 4      11.8
# 5      28.6
# 6      27.4
# 7       4.2
# 8      13.8
# 9      24.3
# 10     83.7
# 11     26.0
# 12     29.4
# 13     17.0
# 14     19.6
# 15     14.6
# 16      0.0
# 17      1.1
# 18      0.6
# 19     37.3
# 20      3.1
# 21      3.2
# 22      9.9
# 23      2.8
# 24     93.4
# 25     12.8
# 26     32.8
# 27     92.5
# 28     23.2
# 29      3.4
#        ...
# 317    10.0
# 318    89.7
# 319     5.8
# 320     0.8
# 321     0.7
# 322     1.7
# 323     2.9
# 324     1.4
# 325    28.8
# 326    36.2
# 327    34.3
# 328     0.8
# 329    39.1
# 330     0.7
# 331    21.6
# 332     2.7
# 333     2.6
# 334     2.7
# 335     2.2
# 336     2.5
# 337    22.4
# 338    23.4
# 339    26.9
# 340     2.5
# 341     5.5
# 342    15.2
# 343     3.3
# 344    11.6
# 345     4.5
# 346    22.3
# Name: percent_black, Length: 347, dtype: float64

# %%
print(df[df.school_rating>3][['name','school_type']])
# Out:
#                                                   name     school_type
# 0                          Allendale Elementary School          Public
# 2                                     Avoca Elementary          Public
# 4                                  Barfield Elementary          Public
# 5                       Barkers Mill Elementary School          Public
# 6                                 Barksdale Elementary          Public
# 7                                     Beech Elementary          Public
# 8                             Beech Senior High School          Public
# 13                          Blackman Elementary School          Public
# 14                                Blackman High School          Public
# 15                              Blackman Middle School          Public
# 18                          Boones Creek Middle School          Public
# 20                               Brentwood High School          Public
# ...

# %%
print(df['school_rating'])
# Out:
# 0      5.0
# 1      2.0
# 2      4.0
# 3      0.0
# 4      4.0
# 5      4.0
# 6      4.0
# 7      5.0
# 8      4.0
# 9      3.0
# 10     0.0
# 11     3.0
# 12     3.0
# 13     5.0
# 14     4.0
# 15     4.0
# 16     2.0
# 17     3.0
# 18     4.0
# 19     1.0
# 20     5.0
# 21     5.0
# 22     4.0
# 23     4.0
# 24     0.0
# 25     3.0
# 26     2.0
# 27     0.0
# 28     0.0
# 29     5.0
#       ...
# 317    4.0
# 318    0.0
# 319    4.0
# 320    4.0
# 321    2.0
# 322    3.0
# 323    2.0
# 324    2.0
# 325    4.0
# 326    3.0
# 327    4.0
# 328    4.0
# 329    3.0
# 330    4.0
# 331    2.0
# 332    4.0
# 333    4.0
# 334    3.0
# 335    3.0
# 336    4.0
# 337    1.0
# 338    3.0
# 339    2.0
# 340    3.0
# 341    4.0
# 342    3.0
# 343    5.0
# 344    4.0
# 345    5.0
# 346    0.0
# Name: school_rating, Length: 347, dtype: float64

# %%
import pandas as pd

pd.__version__
# Out:
# '0.23.4'

# %%
print(df.iloc[342])
# Out:
# name                   Winfree Bryant Middle School
# school_rating                                     3
# size                                            611
# reduced_lunch                                    57
# state_percentile_16                            59.1
# state_percentile_15                            65.2
# stu_teach_ratio                                16.9
# school_type                                  Public
# avg_score_15                                   61.4
# avg_score_16                                   57.7
# full_time_teachers                               36
# percent_black                                  15.2
# percent_white                                  66.3
# percent_asian                                   1.5
# percent_hispanic                               15.7
# Name: 342, dtype: object

# %%
df.count()
# Out:
# name                   347
# school_rating          347
# size                   347
# reduced_lunch          347
# state_percentile_16    347
# state_percentile_15    341
# stu_teach_ratio        347
# school_type            347
# avg_score_15           341
# avg_score_16           347
# full_time_teachers     347
# percent_black          347
# percent_white          347
# percent_asian          347
# percent_hispanic       347
# dtype: int64

# %%
df.shape
# Out:
# (347, 15)

# %%
import sys
sys.version
# Out:
# '3.6.6 |Anaconda, Inc.| (default, Jun 28 2018, 17:14:51) \n[GCC 7.2.0]'

# %%
print(df[df.school_rating>3][['name','school_type']])
# Out:
#                                                   name     school_type
# 0                          Allendale Elementary School          Public
# 2                                     Avoca Elementary          Public
# 4                                  Barfield Elementary          Public
# 5                       Barkers Mill Elementary School          Public
# 6                                 Barksdale Elementary          Public
# 7                                     Beech Elementary          Public
# 8                             Beech Senior High School          Public
# 13                          Blackman Elementary School          Public
# 14                                Blackman High School          Public
# 15                              Blackman Middle School          Public
# 18                          Boones Creek Middle School          Public
# 20                               Brentwood High School          Public
# ...

# %%
print(df[df.school_rating>=4][['school_rating','name','school_type']])
# Out:
#      school_rating                                               name  \
# 0              5.0                        Allendale Elementary School
# 2              4.0                                   Avoca Elementary
# 4              4.0                                Barfield Elementary
# 5              4.0                     Barkers Mill Elementary School
# 6              4.0                               Barksdale Elementary
# 7              5.0                                   Beech Elementary
# 8              4.0                           Beech Senior High School
# 13             5.0                         Blackman Elementary School
# 14             4.0                               Blackman High School
# 15             4.0                             Blackman Middle School
# 18             4.0                         Boones Creek Middle School
# 20             5.0                              Brentwood High School
# ...

# %%
print(df.head())
# Out:
#                           name  school_rating   size  reduced_lunch  \
# 0  Allendale Elementary School            5.0  851.0           10.0
# 1          Anderson Elementary            2.0  412.0           71.0
# 2             Avoca Elementary            4.0  482.0           43.0
# 3                Bailey Middle            0.0  394.0           91.0
# 4          Barfield Elementary            4.0  948.0           26.0
#
#    state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# 0                 90.2                 95.8             15.7         Public
# 1                 32.8                 37.3             12.8         Public
# 2                 78.4                 83.6             16.6         Public
# 3                  1.6                  1.0             13.1  Public Magnet
# 4                 85.3                 89.2             14.8         Public
#
#    avg_score_15  avg_score_16  full_time_teachers  percent_black  \
# ...

# %%
print(df.tail())
# Out:
#                              name  school_rating   size  reduced_lunch  \
# 342  Winfree Bryant Middle School            3.0  611.0           57.0
# 343    Winstead Elementary School            5.0  515.0            8.0
# 344           Woodland Elementary            4.0  424.0           55.0
# 345        Woodland Middle School            5.0  866.0            2.0
# 346                 Wright Middle            0.0  829.0           89.0
#
#      state_percentile_16  state_percentile_15  stu_teach_ratio school_type  \
# 342                 59.1                 65.2             16.9      Public
# 343                 93.9                 97.0             14.3      Public
# 344                 84.8                 76.7             14.1      Public
# 345                 93.3                 97.1             19.2      Public
# 346                  4.5                  1.2             16.5      Public
#
#      avg_score_15  avg_score_16  full_time_teachers  percent_black  \
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 347 entries, 0 to 346
# Data columns (total 15 columns):
# name                   347 non-null object
# school_rating          347 non-null float64
# size                   347 non-null float64
# reduced_lunch          347 non-null float64
# state_percentile_16    347 non-null float64
# state_percentile_15    341 non-null float64
# stu_teach_ratio        347 non-null float64
# school_type            347 non-null object
# avg_score_15           341 non-null float64
# avg_score_16           347 non-null float64
# full_time_teachers     347 non-null float64
# percent_black          347 non-null float64
# percent_white          347 non-null float64
# percent_asian          347 non-null float64
# percent_hispanic       347 non-null float64
# dtypes: float64(13), object(2)
# memory usage: 40.7+ KB
# None

# %%
df.describe()
# Out:
#        school_rating         size  reduced_lunch  state_percentile_16  \
# count     347.000000   347.000000     347.000000           347.000000
# mean        2.968300   699.472622      50.279539            58.801729
# std         1.690377   400.598636      25.480236            32.540747
# min         0.000000    53.000000       2.000000             0.200000
# 25%         2.000000   420.500000      30.000000            30.950000
# 50%         3.000000   595.000000      51.000000            66.400000
# 75%         4.000000   851.000000      71.500000            88.000000
# max         5.000000  2314.000000      98.000000            99.800000
#
#        state_percentile_15  stu_teach_ratio  avg_score_15  avg_score_16  \
# count           341.000000       347.000000    341.000000    347.000000
# mean             58.249267        15.461671     57.004692     57.049856
# std              32.702630         5.725170     26.696450     27.968974
# ...

# %%
df[['reduced_lunch','school_rating']].groupby(['school_rating']).describe()
# Out:
#               reduced_lunch                                                  \
#                       count       mean        std   min    25%   50%    75%
# school_rating
# 0.0                    43.0  83.581395   8.813498  53.0  79.50  86.0  90.00
# 1.0                    40.0  74.950000  11.644191  53.0  65.00  74.5  84.25
# 2.0                    44.0  64.272727  11.956051  37.0  54.75  62.5  74.00
# 3.0                    56.0  50.285714  13.550866  24.0  41.00  48.5  63.00
# 4.0                    86.0  41.000000  16.681092   4.0  30.00  41.5  50.00
# 5.0                    78.0  21.602564  17.651268   2.0   8.00  19.0  29.75
#
#
#                 max
# school_rating
# 0.0            98.0
# 1.0            98.0
# 2.0            88.0
# 3.0            78.0
# 4.0            87.0
# 5.0            87.0

# %%
df[['reduced_lunch','school_rating']].corr()
# Out:
#                reduced_lunch  school_rating
# reduced_lunch       1.000000      -0.815757
# school_rating      -0.815757       1.000000

# %%
fig, ax = plt.subplots(figsize=(14,8))
ax.set_ylabel('school_rating')
# boxplot with only these two variables
_ = df[['reduced_lunch',
'school_rating']].boxplot(by='school_rating',
figsize=(13,8), vert=False, sym='b.', ax=ax)
